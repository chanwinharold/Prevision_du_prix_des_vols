# %% [markdown]
# # Nettoyage et Préparation des données

# %%
import pandas as pd
import datetime

data = pd.read_csv("../data/data_concatenated.csv")
data.head()
# Out:
#          date    airline ch_code  num_code dep_time   from time_taken  \
# 0  11-02-2022  Air India      AI       868    18:00  Delhi    02h 00m
# 1  11-02-2022  Air India      AI       624    19:00  Delhi    02h 15m
# 2  11-02-2022  Air India      AI       531    20:00  Delhi    24h 45m
# 3  11-02-2022  Air India      AI       839    21:25  Delhi    26h 30m
# 4  11-02-2022  Air India      AI       544    17:15  Delhi    06h 40m
#
#                                                 stop arr_time      to   price  \
# 0                                          non-stop     20:00  Mumbai  25,612
# 1                                          non-stop     21:15  Mumbai  25,612
# 2  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45  Mumbai  42,220
# 3  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55  Mumbai  44,450
# 4  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55  Mumbai  46,690
#
#       class
# 0  business
# 1  business
# 2  business
# 3  business
# 4  business

# %% [markdown]
# On commence par supprimer les doublons

# %%
data.drop_duplicates(inplace=True, ignore_index=True)

# %% [markdown]
# On supprime aussi les colonnes inutiles

# %%
data.drop(columns=["ch_code", "stop"], inplace=True)

# %% [markdown]
# On convertis la colonne des prix en valeurs numériques

# %%
data["price"] = data["price"].str.replace(",", "")
data["price"] = pd.to_numeric(data["price"], errors="coerce")

# %% [markdown]
# À présent on convertis les colonnes des dates, des heures d'arrivée et de départ en Objet datetime

# %%
data["date"] = pd.to_datetime(data["date"], format="%d-%m-%Y", errors="coerce")
data["dep_time"] = pd.to_datetime(data["dep_time"], format="%H:%M", errors="coerce").dt.time
data["arr_time"] = pd.to_datetime(data["arr_time"], format="%H:%M", errors="coerce").dt.time

# %% [markdown]
# Transformation de la variable time_taken en Objet datetime

# %%
data["time_taken"] = pd.to_datetime(data["time_taken"], format="%Hh %Mm", errors="coerce").dt.time
data.loc[data["time_taken"].isnull() == True, "time_taken"] = datetime.time(hour=23)

# %% [markdown]
# Enfin on transformera les colonnes ```time_taken```, ```dep_time``` et ```arr_time``` en variables catégorielles
#
# Classement par catégorie :
# - Aube : 04:00 - 06:00
# - Matin : 06:00 - 12:00
# - Après-midi : 12:00 - 18:00
# - Soir : 18:00 - 21:00
# - Nuit : 21:00 - 04:00
#
# Pour la durée on aura :
# - t_court: 0h à 2h
# - court: 2h à 4h
# - moyen: 4h à 8h
# - long: 8h à 12h
# - t_long: +12h

# %%
def classification_time(series):
    if datetime.time(hour=4) <= series < datetime.time(hour=6):
        return "aube"
    elif datetime.time(hour=6) <= series < datetime.time(hour=12):
        return "matin"
    elif datetime.time(hour=12) <= series < datetime.time(hour=18):
        return "apres-midi"
    elif datetime.time(hour=18) <= series < datetime.time(hour=21):
        return "soir"
    else:
        return "nuit"

for i in range(len(data)):
    data.loc[i, "dep_time"] = classification_time(data.loc[i, "dep_time"])
    data.loc[i, "arr_time"] = classification_time(data.loc[i, "arr_time"])

# %%
data[["dep_time", "arr_time"]]
# Out:
#           dep_time arr_time
# 0             soir     soir
# 1             soir     nuit
# 2             soir     soir
# 3             nuit     nuit
# 4       apres-midi     nuit
# ...            ...      ...
# 300254       matin     soir
# 300255       matin     soir
# 300256  apres-midi    matin
# 300257       matin    matin
# 300258        soir     soir
#
# [300259 rows x 2 columns]

# %%
def classification_duree(series):
    if datetime.time(hour=0) <= series < datetime.time(hour=2):
        return "t_court"
    elif datetime.time(hour=2) <= series < datetime.time(hour=4):
        return "court"
    elif datetime.time(hour=4) <= series < datetime.time(hour=8):
        return "moyen"
    elif datetime.time(hour=8) <= series < datetime.time(hour=12):
        return "long"
    else:
        return "t_long"

for i in range(len(data)):
    data.loc[i, "time_taken"] = classification_duree(data.loc[i, "time_taken"])

# %%
data["time_taken"].head(20)
# Out:
# 0      court
# 1      court
# 2     t_long
# 3     t_long
# 4      moyen
# 5      court
# 6     t_long
# 7     t_long
# 8     t_long
# 9      court
# 10      long
# 11    t_long
# 12      long
# 13    t_long
# 14    t_long
# 15    t_long
# 16     moyen
# 17    t_long
# 18    t_long
# 19    t_long
# Name: time_taken, dtype: object

# %%
data.describe()
# Out:
#                                 date       num_code          price
# count                         300259  300259.000000  300259.000000
# mean   2022-03-08 00:06:31.342141696    1417.776883   20883.800386
# min              2022-02-11 00:00:00     101.000000    1105.000000
# 25%              2022-02-25 00:00:00     637.000000    4783.000000
# 50%              2022-03-08 00:00:00     818.000000    7425.000000
# 75%              2022-03-20 00:00:00     927.000000   42521.000000
# max              2022-03-31 00:00:00    9991.000000  123071.000000
# std                              NaN    1974.519951   22695.962230

# %%
data.isnull().sum()
# Out:
# date          0
# airline       0
# num_code      0
# dep_time      0
# from          0
# time_taken    0
# arr_time      0
# to            0
# price         0
# class         0
# dtype: int64

# %% [markdown]
# DataFrame nettoyé

# %%
data.head(20)
# Out:
#          date    airline  num_code    dep_time   from time_taken    arr_time  \
# 0  2022-02-11  Air India       868        soir  Delhi      court        soir
# 1  2022-02-11  Air India       624        soir  Delhi      court        nuit
# 2  2022-02-11  Air India       531        soir  Delhi     t_long        soir
# 3  2022-02-11  Air India       839        nuit  Delhi     t_long        nuit
# 4  2022-02-11  Air India       544  apres-midi  Delhi      moyen        nuit
# 5  2022-02-11    Vistara       985        soir  Delhi      court        nuit
# 6  2022-02-11  Air India       479        nuit  Delhi     t_long  apres-midi
# 7  2022-02-11  Air India       473        soir  Delhi     t_long  apres-midi
# 8  2022-02-11    Vistara       871        soir  Delhi     t_long  apres-midi
# 9  2022-02-11    Vistara       977        soir  Delhi      court        nuit
# 10 2022-02-11  Air India       504        nuit  Delhi       long       matin
# 11 2022-02-11  Air India       807  apres-midi  Delhi     t_long       matin
# 12 2022-02-11  Air India       540        soir  Delhi       long       matin
# 13 2022-02-11  Air India       537  apres-midi  Delhi     t_long       matin
# 14 2022-02-11  Air India       540        soir  Delhi     t_long        soir
# 15 2022-02-11  Air India       537  apres-midi  Delhi     t_long        soir
# 16 2022-02-11    Vistara       817  apres-midi  Delhi      moyen        nuit
# 17 2022-02-11    Vistara       817  apres-midi  Delhi     t_long       matin
# 18 2022-02-11    Vistara       817  apres-midi  Delhi     t_long        soir
# 19 2022-02-11    Vistara       817  apres-midi  Delhi     t_long       matin
#
#         to  price     class
# 0   Mumbai  25612  business
# 1   Mumbai  25612  business
# 2   Mumbai  42220  business
# 3   Mumbai  44450  business
# 4   Mumbai  46690  business
# 5   Mumbai  50264  business
# 6   Mumbai  50669  business
# 7   Mumbai  51059  business
# 8   Mumbai  51731  business
# 9   Mumbai  53288  business
# 10  Mumbai  56081  business
# 11  Mumbai  56081  business
# 12  Mumbai  57074  business
# 13  Mumbai  57074  business
# 14  Mumbai  57074  business
# 15  Mumbai  57074  business
# 16  Mumbai  57868  business
# 17  Mumbai  57868  business
# 18  Mumbai  57868  business
# 19  Mumbai  59996  business

# %% [markdown]
# ### Sauvegarde

# %%
data.to_csv("../data/data_cleaned.csv", index=False)
